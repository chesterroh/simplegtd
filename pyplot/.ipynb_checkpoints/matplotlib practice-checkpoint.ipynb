# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %matplotlib inline

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# plt.plot([1,2,3,4])
# plt.ylabel("some numbers")
# plt.show()
# plt.close()

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show()

# %% [markdown]
# plot( x, y, graph type ) 을 사용하고  plt.axis([ x_start, x_end , y_start, y_end ] )

# %%
t = np.arange(0.,5.,0.2)

plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.ylabel("Y-range")
plt.xlabel("X-range")

plt.axis([0,6,0, 130])
plt.show()

# %%
x = np.arange(0.,5.0,0.2)
y = [ i**2 for i in x]
y2 = [ i**3 for i in x]
line, = plt.plot(x,y,'-')
line.set_antialiased(False)
plt.show()
plt.close()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0,5.0,0.1)
t2 = np.arange(0.0,5.0,0.02)

plt.figure(1)
plt.plot(t1,f(t1),'bo',t2,f(t2),'k')
plt.title("first graph")
plt.xlabel("t1,t2 combined")

plt.figure(2)
plt.plot(t2,np.cos(2*np.pi*t2),'r--')
plt.title("second graph")
plt.show()

# %% [markdown]
# now working with text
